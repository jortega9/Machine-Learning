# %%
import numpy as np
from pandas.io.parsers import read_csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
valores = read_csv('/content/drive/MyDrive/DOCENCIA/22-23/AA/p1/ex1data1.csv', header=None).to_numpy()

print(datos.shape)
print(datos[:10])
# Out:
# (97, 2)
# [[ 6.1101 17.592 ]
#  [ 5.5277  9.1302]
#  [ 8.5186 13.662 ]
#  [ 7.0032 11.854 ]
#  [ 5.8598  6.8233]
#  [ 8.3829 11.886 ]
#  [ 7.4764  4.3483]
#  [ 8.5781 12.    ]
#  [ 6.4862  6.5987]
#  [ 5.0546  3.8166]]
